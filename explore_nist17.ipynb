# %%
from utils.converter import correct_format


correct_format('../data/fastei/nist17/replib.sdf', 
               '../data/fastei/nist17/c_replib.sdf')
correct_format('../data/fastei/nist17/mainlib.sdf', 
               '../data/fastei/nist17/c_mainlib.sdf')
# Out:
# 6612632
# 6651878

# %%
from rdkit import Chem


suppl_main = Chem.SDMolSupplier('../data/fastei/nist17/c_mainlib.sdf')
suppl_rep = Chem.SDMolSupplier('../data/fastei/nist17/c_replib.sdf')
mols_main = [mol for mol in suppl_main if mol]
mols_rep = [mol for mol in suppl_rep if mol]
print(len(mols_main)) # 265928
print(len(mols_rep)) # 
print(type(mols_main[0].GetProp('NISTNO')))

# %%
from rdkit.Chem import AllChem


writer = AllChem.SDWriter('../data/fastei/nist17/cs_mainlib.sdf')
for mol in mols_main:
    smi = Chem.MolToSmiles(mol)
    mol.SetProp('SMILES', smi)
    writer.write(mol)
writer.close()

writer = AllChem.SDWriter('../data/fastei/nist17/cs_replib.sdf')
for mol in mols_rep:
    smi = Chem.MolToSmiles(mol)
    mol.SetProp('SMILES', smi)
    writer.write(mol)
writer.close()

# %%
import pandas as pd


df = pd.read_csv('./data/author/NEIMS_test_11499molecules.csv')
NistNo = df['NISTreplib No.']
print(len(NistNo))
print(type(NistNo[0]))
NistNo = set([str(no) for no in NistNo])
print(NistNo)
# Out:
# 11499
# <class 'numpy.int64'>
# ...

# %%
test_mols_rep = []
for mol in mols_rep:
    if mol.GetProp('NISTNO') in NistNo:
        test_mols_rep.append(mol)
print(len(test_mols_rep))

test_mols_main = []
for mol in mols_main:
    if mol.GetProp('NISTNO') in NistNo:
        test_mols_main.append(mol)
print(len(test_mols_main))
# Out:
# 11499

# %%
from rdkit.Chem import AllChem


writer = AllChem.SDWriter('../data/fastei/nist17/test_11499_rep.sdf')
for mol in test_mols_rep:
    writer.write(mol)
writer.close()

writer = AllChem.SDWriter('../data/fastei/nist17/test_11499.sdf')
for mol in test_mols_main:
    writer.write(mol)
writer.close()

# %%
from utils.converter import NIST17sdf2mgf


NIST17sdf2mgf('../data/fastei/nist17/test_11499_rep.sdf',
              '../data/fastei/nist17/test_11499_rep.mgf')
NIST17sdf2mgf('../data/fastei/nist17/test_11499.sdf',
                '../data/fastei/nist17/test_11499.mgf')

# %%
from matchms import set_matchms_logger_level
set_matchms_logger_level("ERROR")
from matchms.importing import load_from_mgf
import torch as pt 


iter = load_from_mgf('../data/fastei/nist17/test_11499_rep.mgf')
spectra = [s for s in iter]
pt.save(spectra, './data/mine/test_11499_rep.pt')
iter = load_from_mgf('../data/fastei/nist17/test_11499.mgf')
spectra = [s for s in iter]
pt.save(spectra, './data/mine/test_11499.pt')

# %%
from utils.filter import filter_nist


nist_val = open('../data/fastei/nist/validation_set_smiles.txt')
smiles_val = nist_val.readlines()
print(len(smiles_val)) # 11599
_, _, val_smi = filter_nist(smiles_val)

# %%
from rdkit.Chem import AllChem


writer = AllChem.SDWriter('../data/fastei/nist17/val_set.sdf')
mols_val = []
for mol in mols_main:
    if mol.GetProp('SMILES') in val_smi:
        mols_val.append(mol)
        writer.write(mol)
writer.close()

# %%
from utils.converter import NIST17sdf2mgf

NIST17sdf2mgf('../data/fastei/nist17/val_set.sdf', 
              '../data/fastei/nist17/val_set.mgf')
